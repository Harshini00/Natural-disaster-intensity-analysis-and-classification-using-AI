# %%
import tensorflow

# %%
import keras

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPool2D
from tensorflow.keras import layers
from keras.layers import Dropout
from keras.models import load_model
import numpy as np

# %%
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_ds = train_datagen.flow_from_directory('C:/Users/DELL/Desktop/emoji/dataset/train_set', target_size=(64, 64), class_mode='categorical', batch_size=5, color_mode='rgb')

test_ds = train_datagen.flow_from_directory('C:/Users/DELL/Desktop/emoji/dataset/test_set', target_size=(64, 64), class_mode='categorical', batch_size=5,color_mode='rgb')
# Out:
# Found 742 images belonging to 4 classes.
# Found 198 images belonging to 4 classes.

# %%
model = Sequential()

# %%
model.add(Conv2D(32,(3,3), input_shape=(64, 64, 3), activation='relu'))
model.add(MaxPool2D(2,2))
model.add(Dropout(0.2))
model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPool2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 31, 31, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 813604 (3.10 MB)
# Trainable params: 813604 (3.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_ds,
                    steps_per_epoch = len(train_ds),
                    epochs = 20,
                    validation_data = test_ds,
                    validation_steps = len(test_ds))
# Out:
# Epoch 1/20
# 149/149 [==============================] - 72s 459ms/step - loss: 1.2350 - accuracy: 0.4191 - val_loss: 1.0763 - val_accuracy: 0.5000
# Epoch 2/20
# 149/149 [==============================] - 45s 300ms/step - loss: 0.9309 - accuracy: 0.5863 - val_loss: 0.9676 - val_accuracy: 0.5909
# Epoch 3/20
# 149/149 [==============================] - 41s 276ms/step - loss: 0.8622 - accuracy: 0.6334 - val_loss: 0.7592 - val_accuracy: 0.7323
# Epoch 4/20
# 149/149 [==============================] - 34s 226ms/step - loss: 0.8008 - accuracy: 0.6698 - val_loss: 0.8730 - val_accuracy: 0.6465
# Epoch 5/20
# 149/149 [==============================] - 30s 205ms/step - loss: 0.7070 - accuracy: 0.7332 - val_loss: 0.5963 - val_accuracy: 0.7727
# Epoch 6/20
# 149/149 [==============================] - 30s 200ms/step - loss: 0.6521 - accuracy: 0.7439 - val_loss: 0.7585 - val_accuracy: 0.7273
# Epoch 7/20
# 149/149 [==============================] - 30s 200ms/step - loss: 0.6246 - accuracy: 0.7439 - val_loss: 0.5865 - val_accuracy: 0.8030
# Epoch 8/20
# 149/149 [==============================] - 29s 193ms/step - loss: 0.5627 - accuracy: 0.7790 - val_loss: 0.6926 - val_accuracy: 0.7778
# Epoch 9/20
# 149/149 [==============================] - 30s 203ms/step - loss: 0.5542 - accuracy: 0.7911 - val_loss: 0.5698 - val_accuracy: 0.7727
# Epoch 10/20
# 149/149 [==============================] - 31s 206ms/step - loss: 0.5611 - accuracy: 0.7749 - val_loss: 0.6382 - val_accuracy: 0.7626
# Epoch 11/20
# 149/149 [==============================] - 30s 203ms/step - loss: 0.5146 - accuracy: 0.8100 - val_loss: 0.6352 - val_accuracy: 0.7828
# Epoch 12/20
# 149/149 [==============================] - 32s 214ms/step - loss: 0.4640 - accuracy: 0.8261 - val_loss: 0.5409 - val_accuracy: 0.7929
# Epoch 13/20
# 149/149 [==============================] - 30s 205ms/step - loss: 0.4903 - accuracy: 0.8235 - val_loss: 0.8312 - val_accuracy: 0.6667
# Epoch 14/20
# 149/149 [==============================] - 31s 211ms/step - loss: 0.4436 - accuracy: 0.8261 - val_loss: 0.5473 - val_accuracy: 0.8131
# Epoch 15/20
# 149/149 [==============================] - 31s 207ms/step - loss: 0.4652 - accuracy: 0.8221 - val_loss: 0.5495 - val_accuracy: 0.8030
# Epoch 16/20
# 149/149 [==============================] - 31s 206ms/step - loss: 0.4590 - accuracy: 0.8329 - val_loss: 0.6800 - val_accuracy: 0.7828
# Epoch 17/20
# 149/149 [==============================] - 31s 206ms/step - loss: 0.4416 - accuracy: 0.8437 - val_loss: 0.6138 - val_accuracy: 0.8081
# Epoch 18/20
# 149/149 [==============================] - 31s 209ms/step - loss: 0.3911 - accuracy: 0.8612 - val_loss: 0.6149 - val_accuracy: 0.8182
# Epoch 19/20
# 149/149 [==============================] - 32s 216ms/step - loss: 0.3556 - accuracy: 0.8693 - val_loss: 0.5154 - val_accuracy: 0.8586
# Epoch 20/20
# 149/149 [==============================] - 32s 212ms/step - loss: 0.3509 - accuracy: 0.8881 - val_loss: 0.5568 - val_accuracy: 0.8131

# %%
model.save('model.h5')
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
result = model.evaluate(test_ds)
# Out:
# 40/40 [==============================] - 6s 136ms/step - loss: 0.5333 - accuracy: 0.8131

# %%
import pandas as pd
pd.DataFrame(history.history).plot(figsize=(10, 7));

# %%
from keras.preprocessing import image

# %%
model = load_model('model.h5')

# %%
img = image.load_img("C:/Users/DELL/Desktop/emoji/dataset/test_set/Flood/1037.jpg", target_size = (64, 64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
pred = np.argmax(model.predict(x), axis=-1)
pred
# Out:
# 1/1 [==============================] - 1s 502ms/step
# array([2], dtype=int64)

# %%
index = ['Cyclone', 'Earthquake', 'Flood', 'WildFire']
result = np.array(index[pred[0]])
result
# Out:
# array('Flood', dtype='<U5')
